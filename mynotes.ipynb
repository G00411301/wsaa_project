# %% [markdown]
# **My Notes**

# %% [markdown]
# Project is worth 60% of module
#
#
# 1. Flask server provides restful API - Week 6 and 7
# 2. Create web page that allows user interact with API - Week 9 and 10

# %% [markdown]
# ***
# **Walk through notes**

# %% [markdown]
# Sample web application on andrewbeatty1.pythonanywhere.com
#
# Files:
# Server.py - This is the flask app,
#             Server uses the appDAO.py file
# appDAO.py - this is the data access object
# contactviewer.html
# requirements.txt - shows all of the modules required to run the app - generated by typing pip freeze > requirements.txt
# dbconfig.py - just contains a dict of the sql access details
#
#
#
# SQL DB name = my contacts
# table name = contacts
